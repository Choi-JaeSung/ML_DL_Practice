# %% [markdown]
# # PCA(iris)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('../Dataset/iris.csv')

# %%
df = iris.copy()

# %%
df = df.drop(['Id'], axis=1)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df.Species = le.fit_transform(df.Species)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
sns.pairplot(df, hue='Species')
plt.show()

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2022)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
X_train[:10]
# Out:
# array([[-1.71687346, -0.14275618, -1.37660609, -1.28770011],
#        [-0.00509458, -0.82798585,  0.12043504,  0.02404873],
#        [-0.37190434, -1.28480563,  0.17801354,  0.15522361],
#        [-1.10552386, -0.14275618, -1.31902758, -1.28770011],
#        [ 0.72852494, -0.37116607,  0.35074906,  0.15522361],
#        [-1.47233362,  0.77088338, -1.31902758, -1.15652523],
#        [-1.10552386,  0.08565371, -1.26144908, -1.418875  ],
#        [-0.24963442, -1.28480563,  0.12043504, -0.10712616],
#        [-0.86098402,  1.68452294, -1.03113506, -1.02535034],
#        [-0.7387141 , -0.82798585,  0.12043504,  0.2863985 ]])

# %%
X_test[:10]
# Out:
# array([[ 0.72852494, -0.59957596,  1.09926962,  1.20462269],
#        [ 2.19576398, -0.14275618,  1.67505467,  1.20462269],
#        [-1.22779378,  0.08565371, -1.20387057, -1.28770011],
#        [ 0.72852494,  0.08565371,  1.04169112,  0.81109803],
#        [-0.86098402,  0.99929327, -1.31902758, -1.15652523],
#        [-1.71687346, -0.37116607, -1.31902758, -1.28770011],
#        [-0.1273645 , -1.05639574, -0.10987898, -0.23830104],
#        [-0.37190434, -1.51321552,  0.06285653, -0.10712616],
#        [-0.86098402,  0.99929327, -1.31902758, -1.28770011],
#        [-0.00509458, -0.82798585,  0.23559205, -0.23830104]])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
X_train_pca[:10]
# Out:
# array([[-2.39211047, -0.87245821],
#        [ 0.29422853, -0.76451723],
#        [ 0.32820357, -1.31598883],
#        [-2.03926849, -0.64173573],
#        [ 0.76831266, -0.05569783],
#        [-2.39161211,  0.07282594],
#        [-2.13903783, -0.43844084],
#        [ 0.20962822, -1.28709861],
#        [-2.0654977 ,  1.15830736],
#        [ 0.05996191, -1.02412994]])

# %%
plt.scatter(X_train_pca[:, 0], X_train_pca[:, -1], c=y_train)
plt.show()

# %%
# Decision Tree

from sklearn.tree import DecisionTreeClassifier

# %%
dc = DecisionTreeClassifier()

dc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cfm = confusion_matrix(y_test, y_pred)
cfm
# Out:
# array([[ 9,  0,  0],
#        [ 0,  7,  1],
#        [ 0,  1, 12]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9333333333333333

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
cfm = confusion_matrix(y_test, y_pred)
cfm
# Out:
# array([[ 9,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  1, 12]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9666666666666667
