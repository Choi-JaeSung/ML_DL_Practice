# %%
import numpy as np
import pandas as pd
import os
import cv2

# %%
img = []

# %%
for i in range(200):
    img.append(cv2.cvtColor(cv2.resize(cv2.imread(f'./data/mask/mask_{i}.jpg'), (128, 128)), cv2.COLOR_BGR2RGB))

# %%
len(img)
# Out:
# 200

# %%
for i in range(200):
    img.append(cv2.cvtColor(cv2.resize(cv2.imread(f'./data/no_mask/no_mask_{i}.jpg'), (128, 128)), cv2.COLOR_BGR2RGB))

# %%
len(img)
# Out:
# 400

# %%
img = np.array(img, dtype=np.uint)

# %%
img.shape
# Out:
# (400, 128, 128, 3)

# %%
np.savez('./data/img.npz', img = img)

# %%
img = np.load('./data/img.npz')

img['img']
# Out:
# array([[[[129, 121, 124],
#          [131, 123, 120],
#          [136, 128, 117],
#          ...,
#          [128, 114, 106],
#          [123, 114, 105],
#          [124, 116, 107]],
#
#         [[127, 121, 121],
#          [137, 130, 122],
#          [132, 123, 114],
#          ...,
#          [125, 118, 108],
#          [125, 115, 107],
#          [124, 120, 109]],
#
#         [[134, 131, 127],
#          [134, 130, 121],
#          [140, 131, 124],
#          ...,
#          [123, 119, 108],
#          [125, 115, 107],
#          [120, 111, 104]],
#
#         ...,
#
#         [[ 16,  17,  35],
#          [ 12,  13,  31],
#          [ 14,  17,  32],
#          ...,
#          [106,  94, 104],
#          [103, 112, 127],
#          [ 98, 110, 126]],
#
#         [[ 15,  17,  30],
#          [ 12,  14,  29],
#          [ 16,  20,  31],
#          ...,
#          [112, 101, 107],
#          [101, 108, 121],
#          [101, 112, 130]],
#
#         [[ 16,  18,  33],
# ...
